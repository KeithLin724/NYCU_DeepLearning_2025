# %% [markdown]
# **Sources:**
# - Github implementation [Denoising Diffusion Pytorch](https://github.com/lucidrains/denoising-diffusion-pytorch)
# - Papers on Diffusion models ([Dhariwal, Nichol, 2021], [Ho et al., 2020] ect.)

# %% [markdown]
# ## Import Packages and Set Seeds

# %%
# %pip install einops transformers ema_pytorch accelerate

# %%
import math
import copy
from pathlib import Path
from random import random
from functools import partial
from collections import namedtuple
from multiprocessing import cpu_count

import torch
from torch import nn, einsum
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader

from torch.optim import Adam

import torchvision
from torchvision import transforms as T, utils

from einops import rearrange, reduce, repeat
from einops.layers.torch import Rearrange

from PIL import Image
from tqdm import tqdm
from ema_pytorch import EMA

from accelerate import Accelerator
import matplotlib.pyplot as plt
import os
from typing import Callable, Iterable


torch.backends.cudnn.benchmark = True
torch.manual_seed(4096)

if torch.cuda.is_available():
  torch.cuda.manual_seed(4096)

# %%
OUTPUT_DIR = "./"
DATASET_DIR = "face_dataset"

# %% [markdown]
# ## Step 1: Forward process (Noise scheduler)

# %%
def linear_beta_schedule(timesteps:int):
    """
    linear schedule, proposed in original ddpm paper
    """
    scale = 1000 / timesteps
    beta_start = scale * 0.0001
    beta_end = scale * 0.02
    return torch.linspace(beta_start, beta_end, timesteps, dtype = torch.float64)

def extract(a:torch.Tensor, t:torch.Tensor, x_shape:list):
    b, *_ = t.shape
    out = a.gather(-1, t)
    return out.reshape(b, *((1,) * (len(x_shape) - 1)))

# %% [markdown]
# Create dataset

# %%
class Dataset(Dataset):
    def __init__(
        self,
        folder,
        image_size
    ):
        self.folder = folder
        self.image_size = image_size
        self.paths = [p for p in Path(f'{folder}').glob(f'**/*.jpg')]
        #################################
        ## TODO: Data Augmentation ##
        #################################
        self.transform = T.Compose([
            T.Resize(image_size),
            T.ToTensor()
        ])

    def __len__(self):
        return len(self.paths)

    def __getitem__(self, index):
        path = self.paths[index]
        img = Image.open(path)
        return self.transform(img)

# %% [markdown]
# ## Step 2: The backward process = U-Net

# %% [markdown]
# Define some useful functions and U-Net

# %%
def exists(x):
    return x is not None

def default(val, d:Callable):
    if exists(val):
        return val
    return d() if callable(d) else d

def identity(t, *args, **kwargs):
    return t

def cycle(dl:Iterable):
    while True:
        for data in dl:
            yield data

def has_int_squareroot(num:int):
    return (math.sqrt(num) ** 2) == num

def num_to_groups(num:int, divisor:int):
    groups = num // divisor
    remainder = num % divisor
    arr = [divisor] * groups
    if remainder > 0:
        arr.append(remainder)
    return arr

# normalization functions

def normalize_to_neg_one_to_one(img:torch.Tensor):
    return img * 2 - 1

def unnormalize_to_zero_to_one(t:torch.Tensor):
    return (t + 1) * 0.5

# small helper modules

class Residual(nn.Module):
    def __init__(self, fn:Callable):
        super().__init__()
        self.fn = fn

    def forward(self, x, *args, **kwargs):
        return self.fn(x, *args, **kwargs) + x

def Upsample(dim:int, dim_out = None):
    return nn.Sequential(
        nn.Upsample(scale_factor = 2, mode = 'nearest'),
        nn.Conv2d(dim, default(dim_out, dim), 3, padding = 1)
    )

def Downsample(dim:int, dim_out = None):
    return nn.Sequential(
        Rearrange('b c (h p1) (w p2) -> b (c p1 p2) h w', p1 = 2, p2 = 2),
        nn.Conv2d(dim * 4, default(dim_out, dim), 1)
    )

class WeightStandardizedConv2d(nn.Conv2d):
    """
    https://arxiv.org/abs/1903.10520
    weight standardization purportedly works synergistically with group normalization
    """
    def forward(self, x:torch.Tensor):
        eps = 1e-5 if x.dtype == torch.float32 else 1e-3

        weight = self.weight
        mean = reduce(weight, 'o ... -> o 1 1 1', 'mean')
        var = reduce(weight, 'o ... -> o 1 1 1', partial(torch.var, unbiased = False))
        normalized_weight = (weight - mean) * (var + eps).rsqrt()

        return F.conv2d(x, normalized_weight, self.bias, self.stride, self.padding, self.dilation, self.groups)

class LayerNorm(nn.Module):
    def __init__(self, dim:int):
        super().__init__()
        self.g = nn.Parameter(torch.ones(1, dim, 1, 1))

    def forward(self, x: torch.Tensor):
        eps = 1e-5 if x.dtype == torch.float32 else 1e-3
        var = torch.var(x, dim = 1, unbiased = False, keepdim = True)
        mean = torch.mean(x, dim = 1, keepdim = True)
        return (x - mean) * (var + eps).rsqrt() * self.g

class PreNorm(nn.Module):
    def __init__(self, dim:int, fn: Callable):
        super().__init__()
        self.fn = fn
        self.norm = LayerNorm(dim) 

    def forward(self, x: torch.Tensor):
        x = self.norm(x)
        return self.fn(x)

# sinusoidal positional embeds

class SinusoidalPosEmb(nn.Module):
    def __init__(self, dim:int):
        super().__init__()
        self.dim = dim

    def forward(self, x: torch.Tensor):
        device = x.device
        half_dim = self.dim // 2
        emb = math.log(10000) / (half_dim - 1)
        emb = torch.exp(torch.arange(half_dim, device=device) * -emb)
        emb = x[:, None] * emb[None, :]
        emb = torch.cat((emb.sin(), emb.cos()), dim=-1)
        return emb

class RandomOrLearnedSinusoidalPosEmb(nn.Module):
    """ following @crowsonkb 's lead with random (learned optional) sinusoidal pos emb """
    """ https://github.com/crowsonkb/v-diffusion-jax/blob/master/diffusion/models/danbooru_128.py#L8 """

    def __init__(self, dim:int, is_random: bool = False):
        super().__init__()
        assert (dim % 2) == 0
        half_dim = dim // 2
        self.weights = nn.Parameter(torch.randn(half_dim), requires_grad = not is_random)

    def forward(self, x: torch.Tensor):
        x = rearrange(x, 'b -> b 1')
        freqs = x * rearrange(self.weights, 'd -> 1 d') * 2 * math.pi
        fouriered = torch.cat((freqs.sin(), freqs.cos()), dim = -1)
        fouriered = torch.cat((x, fouriered), dim = -1)
        return fouriered

# building block modules

class Block(nn.Module):
    def __init__(self, dim:int, dim_out:int, groups:int = 8):
        super().__init__()
        self.proj = WeightStandardizedConv2d(dim, dim_out, 3, padding = 1)
        self.norm = nn.GroupNorm(groups, dim_out)
        self.act = nn.SiLU()

    def forward(self, x: torch.Tensor, scale_shift = None):
        x = self.proj(x)
        x = self.norm(x)

        if exists(scale_shift):
            scale, shift = scale_shift
            x = x * (scale + 1) + shift

        x = self.act(x)
        return x

class ResnetBlock(nn.Module):
    def __init__(self, dim:int, dim_out:int, *, time_emb_dim:int | None = None, groups:int = 8):
        super().__init__()
        self.mlp = nn.Sequential(
            nn.SiLU(),
            nn.Linear(time_emb_dim, dim_out * 2)
        ) if exists(time_emb_dim) else None

        self.block1 = Block(dim, dim_out, groups = groups)
        self.block2 = Block(dim_out, dim_out, groups = groups)
        self.res_conv = nn.Conv2d(dim, dim_out, 1) if dim != dim_out else nn.Identity()

    def forward(self, x: torch.Tensor, time_emb = None):

        scale_shift = None
        if exists(self.mlp) and exists(time_emb):
            time_emb = self.mlp(time_emb)
            time_emb = rearrange(time_emb, 'b c -> b c 1 1')
            scale_shift = time_emb.chunk(2, dim = 1)

        h = self.block1(x, scale_shift = scale_shift)

        h = self.block2(h)

        return h + self.res_conv(x)

class LinearAttention(nn.Module):
    def __init__(self, dim, heads = 4, dim_head = 32):
        super().__init__()
        self.scale = dim_head ** -0.5
        self.heads = heads
        hidden_dim = dim_head * heads
        self.to_qkv = nn.Conv2d(dim, hidden_dim * 3, 1, bias = False)

        self.to_out = nn.Sequential(
            nn.Conv2d(hidden_dim, dim, 1),
            LayerNorm(dim)
        )

    def forward(self, x):
        b, c, h, w = x.shape
        qkv = self.to_qkv(x).chunk(3, dim = 1)
        q, k, v = map(lambda t: rearrange(t, 'b (h c) x y -> b h c (x y)', h = self.heads), qkv)

        q = q.softmax(dim = -2)
        k = k.softmax(dim = -1)

        q = q * self.scale
        v = v / (h * w)

        context = torch.einsum('b h d n, b h e n -> b h d e', k, v)

        out = torch.einsum('b h d e, b h d n -> b h e n', context, q)
        out = rearrange(out, 'b h c (x y) -> b (h c) x y', h = self.heads, x = h, y = w)
        return self.to_out(out)

class Attention(nn.Module):
    def __init__(self, dim, heads = 4, dim_head = 32):
        super().__init__()
        self.scale = dim_head ** -0.5
        self.heads = heads
        hidden_dim = dim_head * heads

        self.to_qkv = nn.Conv2d(dim, hidden_dim * 3, 1, bias = False)
        self.to_out = nn.Conv2d(hidden_dim, dim, 1)

    def forward(self, x):
        b, c, h, w = x.shape
        qkv = self.to_qkv(x).chunk(3, dim = 1)
        q, k, v = map(lambda t: rearrange(t, 'b (h c) x y -> b h c (x y)', h = self.heads), qkv)

        q = q * self.scale

        sim = torch.einsum('b h d i, b h d j -> b h i j', q, k)
        attn = sim.softmax(dim = -1)
        out = torch.einsum('b h i j, b h d j -> b h i d', attn, v)

        out = rearrange(out, 'b h (x y) d -> b (h d) x y', x = h, y = w)
        return self.to_out(out)

# model

class Unet(nn.Module):
    def __init__(
        self,
        dim,
        init_dim = None,
        out_dim = None,
        dim_mults=(1, 2, 4, 8),
        channels = 3,
        resnet_block_groups = 8,
        learned_sinusoidal_cond = False,
        random_fourier_features = False,
        learned_sinusoidal_dim = 16
    ):
        super().__init__()

        # determine dimensions

        self.channels = channels

        init_dim = default(init_dim, dim)
        self.init_conv = nn.Conv2d(channels, init_dim, 7, padding = 3)

        dims = [init_dim, *map(lambda m: dim * m, dim_mults)]
        in_out = list(zip(dims[:-1], dims[1:]))

        block_klass = partial(ResnetBlock, groups = resnet_block_groups)

        # time embeddings

        time_dim = dim * 4

        self.random_or_learned_sinusoidal_cond = learned_sinusoidal_cond or random_fourier_features

        if self.random_or_learned_sinusoidal_cond:
            sinu_pos_emb = RandomOrLearnedSinusoidalPosEmb(learned_sinusoidal_dim, random_fourier_features)
            fourier_dim = learned_sinusoidal_dim + 1
        else:
            sinu_pos_emb = SinusoidalPosEmb(dim)
            fourier_dim = dim

        self.time_mlp = nn.Sequential(
            sinu_pos_emb,
            nn.Linear(fourier_dim, time_dim),
            nn.GELU(),
            nn.Linear(time_dim, time_dim)
        )

        # layers

        self.downs = nn.ModuleList([])
        self.ups = nn.ModuleList([])
        num_resolutions = len(in_out)

        for ind, (dim_in, dim_out) in enumerate(in_out):
            is_last = ind >= (num_resolutions - 1)

            self.downs.append(nn.ModuleList([
                block_klass(dim_in, dim_in, time_emb_dim = time_dim),
                block_klass(dim_in, dim_in, time_emb_dim = time_dim),
                Residual(PreNorm(dim_in, LinearAttention(dim_in))),
                Downsample(dim_in, dim_out) if not is_last else nn.Conv2d(dim_in, dim_out, 3, padding = 1)
            ]))

        mid_dim = dims[-1]
        self.mid_block1 = block_klass(mid_dim, mid_dim, time_emb_dim = time_dim)
        self.mid_attn = Residual(PreNorm(mid_dim, Attention(mid_dim)))
        self.mid_block2 = block_klass(mid_dim, mid_dim, time_emb_dim = time_dim)

        for ind, (dim_in, dim_out) in enumerate(reversed(in_out)):
            is_last = ind == (len(in_out) - 1)

            self.ups.append(nn.ModuleList([
                block_klass(dim_out + dim_in, dim_out, time_emb_dim = time_dim),
                block_klass(dim_out + dim_in, dim_out, time_emb_dim = time_dim),
                Residual(PreNorm(dim_out, LinearAttention(dim_out))),
                Upsample(dim_out, dim_in) if not is_last else  nn.Conv2d(dim_out, dim_in, 3, padding = 1)
            ]))

        self.out_dim = default(out_dim, channels)

        self.final_res_block = block_klass(dim * 2, dim, time_emb_dim = time_dim)
        self.final_conv = nn.Conv2d(dim, self.out_dim, 1)

    def forward(self, x, time):
        x = self.init_conv(x)
        r = x.clone()

        t = self.time_mlp(time)

        h = []

        for block1, block2, attn, downsample in self.downs:
            x = block1(x, t)
            h.append(x)

            x = block2(x, t)
            x = attn(x)
            h.append(x)

            x = downsample(x)

        x = self.mid_block1(x, t)
        x = self.mid_attn(x)
        x = self.mid_block2(x, t)

        for block1, block2, attn, upsample in self.ups:
            x = torch.cat((x, h.pop()), dim = 1)
            x = block1(x, t)

            x = torch.cat((x, h.pop()), dim = 1)
            x = block2(x, t)
            x = attn(x)

            x = upsample(x)

        x = torch.cat((x, r), dim = 1)

        x = self.final_res_block(x, t)
        return self.final_conv(x)
model = Unet(64)

# %% [markdown]
# ## Step 3: The Diffusion Process

# %% [markdown]
# Define diffusion process, including generating noisy models, sample...

# %%
class GaussianDiffusion(nn.Module):
    def __init__(
        self,
        model,
        *,
        image_size,
        timesteps = 1000,
        beta_schedule = 'linear',
        auto_normalize = True
    ):
        super().__init__()
        assert not (type(self) == GaussianDiffusion and model.channels != model.out_dim)
        assert not model.random_or_learned_sinusoidal_cond

        self.model = model

        self.channels = self.model.channels

        self.image_size = image_size


        if beta_schedule == 'linear':
            beta_schedule_fn = linear_beta_schedule
        else:
            raise ValueError(f'unknown beta schedule {beta_schedule}')
        
        # calculate beta and other precalculated parameters
        betas = beta_schedule_fn(timesteps)
                                            
        alphas = 1. - betas
        alphas_cumprod = torch.cumprod(alphas, dim=0)
        alphas_cumprod_prev = F.pad(alphas_cumprod[:-1], (1, 0), value = 1.)

        timesteps, = betas.shape
        self.num_timesteps = int(timesteps)

        # sampling related parameters

        self.sampling_timesteps = timesteps # default num sampling timesteps to number of timesteps at training

        # helper function to register buffer from float64 to float32

        register_buffer = lambda name, val: self.register_buffer(name, val.to(torch.float32))

        register_buffer('betas', betas)
        register_buffer('alphas_cumprod', alphas_cumprod)
        register_buffer('alphas_cumprod_prev', alphas_cumprod_prev)

        # calculations for diffusion q(x_t | x_{t-1}) and others

        register_buffer('sqrt_alphas_cumprod', torch.sqrt(alphas_cumprod))
        register_buffer('sqrt_one_minus_alphas_cumprod', torch.sqrt(1. - alphas_cumprod))
        register_buffer('log_one_minus_alphas_cumprod', torch.log(1. - alphas_cumprod))
        register_buffer('sqrt_recip_alphas_cumprod', torch.sqrt(1. / alphas_cumprod))
        register_buffer('sqrt_recipm1_alphas_cumprod', torch.sqrt(1. / alphas_cumprod - 1))

        # calculations for posterior q(x_{t-1} | x_t, x_0)

        posterior_variance = betas * (1. - alphas_cumprod_prev) / (1. - alphas_cumprod)

        # above: equal to 1. / (1. / (1. - alpha_cumprod_tm1) + alpha_t / beta_t)

        register_buffer('posterior_variance', posterior_variance)

        # below: log calculation clipped because the posterior variance is 0 at the beginning of the diffusion chain

        register_buffer('posterior_log_variance_clipped', torch.log(posterior_variance.clamp(min =1e-20)))
        register_buffer('posterior_mean_coef1', betas * torch.sqrt(alphas_cumprod_prev) / (1. - alphas_cumprod))
        register_buffer('posterior_mean_coef2', (1. - alphas_cumprod_prev) * torch.sqrt(alphas) / (1. - alphas_cumprod))

        # derive loss weight
        # snr - signal noise ratio

        snr = alphas_cumprod / (1 - alphas_cumprod)

        # https://arxiv.org/abs/2303.09556

        maybe_clipped_snr = snr.clone()

        register_buffer('loss_weight', maybe_clipped_snr / snr)

        # auto-normalization of data [0, 1] -> [-1, 1] - can turn off by setting it to be False

        self.normalize = normalize_to_neg_one_to_one if auto_normalize else identity
        self.unnormalize = unnormalize_to_zero_to_one if auto_normalize else identity

    def predict_start_from_noise(self, x_t, t, noise):
        return (
            extract(self.sqrt_recip_alphas_cumprod, t, x_t.shape) * x_t -
            extract(self.sqrt_recipm1_alphas_cumprod, t, x_t.shape) * noise
        )

    def predict_noise_from_start(self, x_t, t, x0):
        return (
            (extract(self.sqrt_recip_alphas_cumprod, t, x_t.shape) * x_t - x0) / \
            extract(self.sqrt_recipm1_alphas_cumprod, t, x_t.shape)
        )


    def q_posterior(self, x_start, x_t, t):
        posterior_mean = (
            extract(self.posterior_mean_coef1, t, x_t.shape) * x_start +
            extract(self.posterior_mean_coef2, t, x_t.shape) * x_t
        )
        posterior_variance = extract(self.posterior_variance, t, x_t.shape)
        posterior_log_variance_clipped = extract(self.posterior_log_variance_clipped, t, x_t.shape)
        return posterior_mean, posterior_variance, posterior_log_variance_clipped

    def model_predictions(self, x, t, clip_x_start = False, rederive_pred_noise = False):
        model_output = self.model(x, t)
        maybe_clip = partial(torch.clamp, min = -1., max = 1.) if clip_x_start else identity

        pred_noise = model_output
        x_start = self.predict_start_from_noise(x, t, pred_noise)
        x_start = maybe_clip(x_start)

        if clip_x_start and rederive_pred_noise:
            pred_noise = self.predict_noise_from_start(x, t, x_start)

        return pred_noise, x_start

    def p_mean_variance(self, x, t, clip_denoised = True):
        noise, x_start = self.model_predictions(x, t)

        if clip_denoised:
            x_start.clamp_(-1., 1.)

        model_mean, posterior_variance, posterior_log_variance = self.q_posterior(x_start = x_start, x_t = x, t = t)
        return model_mean, posterior_variance, posterior_log_variance, x_start

    @torch.no_grad()
    def p_sample(self, x, t: int):
        b, *_, device = *x.shape, x.device
        batched_times = torch.full((b,), t, device = x.device, dtype = torch.long)
        model_mean, _, model_log_variance, x_start = self.p_mean_variance(x = x, t = batched_times, clip_denoised = True)
        noise = torch.randn_like(x) if t > 0 else 0. # no noise if t == 0
        pred_img = model_mean + (0.5 * model_log_variance).exp() * noise
        return pred_img, x_start

    @torch.no_grad()
    def p_sample_loop(self, shape, return_all_timesteps = False):
        batch, device = shape[0], self.betas.device

        img = torch.randn(shape, device = device)
        imgs = [img]

        x_start = None
        
        ###########################################
        ## TODO: plot the sampling process ##
        ###########################################
        for t in tqdm(reversed(range(0, self.num_timesteps)), desc = 'sampling loop time step', total = self.num_timesteps):
            img, x_start = self.p_sample(img, t)
            imgs.append(img)
        
        ret = img if not return_all_timesteps else torch.stack(imgs, dim = 1)

        ret = self.unnormalize(ret)
        return ret

    @torch.no_grad()
    def sample(self, batch_size = 16, return_all_timesteps = False):
        image_size, channels = self.image_size, self.channels
        sample_fn = self.p_sample_loop
        return sample_fn((batch_size, channels, image_size, image_size), return_all_timesteps = return_all_timesteps)


    def q_sample(self, x_start, t, noise=None):
        noise = default(noise, lambda: torch.randn_like(x_start))

        return (
            extract(self.sqrt_alphas_cumprod, t, x_start.shape) * x_start +
            extract(self.sqrt_one_minus_alphas_cumprod, t, x_start.shape) * noise
        )

    @property
    def loss_fn(self):
        return F.mse_loss


    def p_losses(self, x_start, t, noise = None):
        b, c, h, w = x_start.shape
        noise = default(noise, lambda: torch.randn_like(x_start))

        # noise sample

        x = self.q_sample(x_start = x_start, t = t, noise = noise)

        # predict and take gradient step

        model_out = self.model(x, t)

        loss = self.loss_fn(model_out, noise, reduction = 'none')
        loss = reduce(loss, 'b ... -> b (...)', 'mean')

        loss = loss * extract(self.loss_weight, t, loss.shape)
        return loss.mean()

    def forward(self, img, *args, **kwargs):
        b, c, h, w, device, img_size, = *img.shape, img.device, self.image_size
        assert h == img_size and w == img_size, f'height and width of image must be {img_size}'
        t = torch.randint(0, self.num_timesteps, (b,), device=device).long()

        img = self.normalize(img)
        return self.p_losses(img, t, *args, **kwargs)

# %% [markdown]
# Define Trainer: define the updating process

# %%
class Trainer:
    def __init__(
        self,
        diffusion_model,
        folder,
        *,
        train_batch_size = 16,
        gradient_accumulate_every = 1,
        train_lr = 1e-4,
        train_num_steps = 100000,
        ema_update_every = 10,
        ema_decay = 0.995,
        adam_betas = (0.9, 0.99),
        save_and_sample_every = 1000,
        num_samples = 25,
        results_folder = './results',
        split_batches = True,
        inception_block_idx = 2048
    ):
        super().__init__()

        # accelerator

        self.accelerator = Accelerator(
            split_batches = split_batches,
            mixed_precision = 'no'
        )
        

        # model

        self.model = diffusion_model
        self.channels = diffusion_model.channels

        # sampling and training hyperparameters

        assert has_int_squareroot(num_samples), 'number of samples must have an integer square root'
        self.num_samples = num_samples
        self.save_and_sample_every = save_and_sample_every

        self.batch_size = train_batch_size
        self.gradient_accumulate_every = gradient_accumulate_every

        self.train_num_steps = train_num_steps
        self.image_size = diffusion_model.image_size

        # dataset and dataloader

        self.ds = Dataset(folder, self.image_size)
        dl = DataLoader(self.ds, batch_size = train_batch_size, shuffle = True, pin_memory = True, num_workers = cpu_count())

        dl = self.accelerator.prepare(dl)
        self.dl = cycle(dl)

        # optimizer

        self.opt = Adam(diffusion_model.parameters(), lr = train_lr, betas = adam_betas)

        # for logging results in a folder periodically

        if self.accelerator.is_main_process:
            self.ema = EMA(diffusion_model, beta = ema_decay, update_every = ema_update_every)
            self.ema.to(self.device)

        self.results_folder = Path(results_folder)
        self.results_folder.mkdir(exist_ok = True)

        # step counter state

        self.step = 0

        # prepare model, dataloader, optimizer with accelerator

        self.model, self.opt = self.accelerator.prepare(self.model, self.opt)

    @property
    def device(self):
        return self.accelerator.device

    def save(self, milestone):
        if not self.accelerator.is_local_main_process:
            return

        data = {
            'step': self.step,
            'model': self.accelerator.get_state_dict(self.model),
            'opt': self.opt.state_dict(),
            'ema': self.ema.state_dict(),
            'scaler': self.accelerator.scaler.state_dict() if exists(self.accelerator.scaler) else None,
        }

        torch.save(data, str(self.results_folder / f'model-{milestone}.pt'))

    def load(self, ckpt:str):
        accelerator = self.accelerator
        device = accelerator.device

        data = torch.load(ckpt, map_location=device)

        model = self.accelerator.unwrap_model(self.model)
        model.load_state_dict(data['model'])

        self.step = data['step']
        self.opt.load_state_dict(data['opt'])
        if self.accelerator.is_main_process:
            self.ema.load_state_dict(data["ema"])


        if exists(self.accelerator.scaler) and exists(data['scaler']):
            self.accelerator.scaler.load_state_dict(data['scaler'])


    def train(self):
        accelerator = self.accelerator
        device = accelerator.device

        with tqdm(initial = self.step, total = self.train_num_steps, disable = not accelerator.is_main_process) as pbar:

            while self.step < self.train_num_steps:

                total_loss = 0.

                for _ in range(self.gradient_accumulate_every):
                    data = next(self.dl).to(device)

                    with self.accelerator.autocast():
                        loss = self.model(data)
                        loss = loss / self.gradient_accumulate_every
                        total_loss += loss.item()

                    self.accelerator.backward(loss)

                accelerator.clip_grad_norm_(self.model.parameters(), 1.0)
                pbar.set_description(f'loss: {total_loss:.4f}')

                accelerator.wait_for_everyone()

                self.opt.step()
                self.opt.zero_grad()

                accelerator.wait_for_everyone()

                self.step += 1
                if accelerator.is_main_process:
                    self.ema.update()

                    if self.step != 0 and self.step % self.save_and_sample_every == 0:
                        self.ema.ema_model.eval()

                        with torch.no_grad():
                            milestone = self.step // self.save_and_sample_every
                            batches = num_to_groups(self.num_samples, self.batch_size)
                            all_images_list = list(map(lambda n: self.ema.ema_model.sample(batch_size=n), batches))

                        all_images = torch.cat(all_images_list, dim = 0)

                        utils.save_image(all_images, str(self.results_folder / f'sample-{milestone}.png'), nrow = int(math.sqrt(self.num_samples)))
                        
                        self.save(milestone)

                pbar.update(1)

        accelerator.print('training complete')
        
    @torch.no_grad()
    @torch.inference_mode()
    def inference(self, num:int=1000, n_iter:int=5, output_path:str='./submission'):
        if not os.path.exists(output_path):
            os.mkdir(output_path)
        
        for i in range(n_iter):
            batches = num_to_groups(num // n_iter, 200)
            
            
            all_images = [
                self.ema.ema_model.sample(batch_size=n) 
                for n in batches
            ]
            all_images = torch.cat(all_images, dim = 0)
            
            for j in range(all_images.shape[0]):
                torchvision.utils.save_image(all_images[j], f'{output_path}/{i * 200 + j + 1}.jpg')

            torch.cuda.empty_cache()
    
    @torch.no_grad()
    @torch.inference_mode()
    def inference_plus(self, batch_size:int=100, n_iter:int=10, output_path:str='./submission'):
        if not os.path.exists(output_path):
            os.mkdir(output_path)
        print("total number of images: ", batch_size * n_iter)
        for i in range(n_iter):
            
            all_images = self.ema.ema_model.sample(batch_size=batch_size) 
            # all_images = torch.cat(all_images, dim = 0)
            
            for j in range(all_images.shape[0]):
                torchvision.utils.save_image(all_images[j], f'{output_path}/{i * batch_size + j + 1}.jpg')

            torch.cuda.empty_cache() 
            print("Finished generating images for iteration: ", i + 1)
        print("Finished generating all images.")
    
    @torch.inference_mode()
    def sample_diffusion_plot(self):
        # import matplotlib.pyplot as plt

        # Generate all timesteps of the diffusion process
        all_timesteps = self.ema.ema_model.sample(batch_size=1, return_all_timesteps=True)
        torch.cuda.empty_cache()
        
        all_timesteps = all_timesteps.squeeze(0).cpu()

        # Plot a few timesteps for visualization
        num_plots = 5
        fig, axes = plt.subplots(1, num_plots, figsize=(15, 3))
        for i in range(num_plots):
            img = all_timesteps[i * 250  ]
            img = img.permute(1, 2, 0).numpy()  # Change to HWC format for visualization
            
            axes[i].imshow(img.clip(0, 1))
            axes[i].axis('off')
            axes[i].set_title(f"Step {i+1}")
        plt.tight_layout()
        plt.show()
        return

# %% [markdown]
# # Training Hyper-parameters

# %%
path = os.path.join(OUTPUT_DIR, DATASET_DIR)   # 请确保路径正确
IMG_SIZE = 64             # 图像尺寸，如果不清楚原因请不要更改
batch_size = 64         # 批量大小
train_num_steps = 50000   # 总训练步数
lr = 5e-5                 # 学习率
grad_steps = 1            # 梯度累积步数，实际更新的等效批量大小为 batch_size * grad_steps = 16 * 1
ema_decay = 0.998         # 指数滑动平均衰减系数

channels = 16             # CNN第一层的通道数
dim_mults = (1, 2, 4, 8)     # 模型尺寸将为 (channels, 2 * channels, 4 * channels, 4 * channels, 2 * channels, channels)

timesteps = 1000          # 噪声添加的步数
beta_schedule = 'linear'  # beta调度方式

model = Unet(
    dim = channels,
    dim_mults = dim_mults
)

diffusion = GaussianDiffusion(
    model,
    image_size = IMG_SIZE,
    timesteps = timesteps,
    beta_schedule = beta_schedule
)

trainer = Trainer(
    diffusion,
    path,
    train_batch_size = batch_size,
    train_lr = lr,
    train_num_steps = train_num_steps,
    gradient_accumulate_every = grad_steps,
    ema_decay = ema_decay,
    save_and_sample_every = 1000,
    results_folder=os.path.join(OUTPUT_DIR, 'results'),
)

# %%
trainer.train()
# Out:
# sampling loop time step: 100%|██████████| 1000/1000 [00:20<00:00, 48.01it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:20<00:00, 48.07it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:20<00:00, 47.69it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:20<00:00, 47.99it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 47.16it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 47.20it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 47.46it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:20<00:00, 47.95it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.95it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 47.34it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.61it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 47.40it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.78it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:20<00:00, 47.86it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.62it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 47.10it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 47.12it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.31it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.45it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.75it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.56it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.86it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.89it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.54it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.36it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.36it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 47.40it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.64it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.53it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.75it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.24it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.00it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.69it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.34it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 45.78it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 45.80it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.95it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.68it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 45.97it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.25it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 46.39it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 45.47it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 45.59it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 45.72it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:21<00:00, 45.69it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:23<00:00, 42.93it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:23<00:00, 42.05it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:23<00:00, 42.48it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:23<00:00, 43.09it/s]
# sampling loop time step: 100%|██████████| 1000/1000 [00:23<00:00, 42.17it/s]
# loss: 0.0224: 100%|██████████| 50000/50000 [2:13:44<00:00,  6.23it/s]
# training complete

# %% [markdown]
# # Inference

# %%
best_model = "model-50.pt"

ckpt = os.path.join(OUTPUT_DIR, 'results', best_model)
trainer.load(ckpt)

# %%
trainer.sample_diffusion_plot()
# Out:
# sampling loop time step: 100%|██████████| 1000/1000 [00:18<00:00, 54.45it/s]

# %%
trainer.inference_plus(batch_size=100, n_iter=10)
# Out:
# total number of images:  1000
# sampling loop time step: 100%|██████████| 1000/1000 [01:11<00:00, 13.97it/s]
# Finished generating images for iteration:  1
# sampling loop time step: 100%|██████████| 1000/1000 [01:11<00:00, 13.95it/s]
# Finished generating images for iteration:  2
# sampling loop time step: 100%|██████████| 1000/1000 [01:11<00:00, 13.93it/s]
# Finished generating images for iteration:  3
# sampling loop time step: 100%|██████████| 1000/1000 [01:11<00:00, 13.93it/s]
# Finished generating images for iteration:  4
# sampling loop time step: 100%|██████████| 1000/1000 [01:11<00:00, 13.93it/s]
# Finished generating images for iteration:  5
# sampling loop time step: 100%|██████████| 1000/1000 [01:11<00:00, 13.93it/s]
# Finished generating images for iteration:  6
# sampling loop time step: 100%|██████████| 1000/1000 [01:11<00:00, 13.93it/s]
# Finished generating images for iteration:  7
# sampling loop time step: 100%|██████████| 1000/1000 [01:11<00:00, 13.93it/s]
# Finished generating images for iteration:  8
# sampling loop time step: 100%|██████████| 1000/1000 [01:11<00:00, 13.93it/s]
# Finished generating images for iteration:  9
# sampling loop time step: 100%|██████████| 1000/1000 [01:11<00:00, 13.92it/s]
# Finished generating images for iteration:  10
# Finished generating all images.

# %%
# %cd ./submission
# !zip -r ../submission.zip .
# %cd ..
# Out:
# /home/keithlin/Code/Python/NYCU_DeepLearning_2025/HW2/2/submission
#   adding: 737.jpg (deflated 8%)
#   adding: 339.jpg (deflated 9%)
#   adding: 553.jpg (deflated 10%)
#   adding: 968.jpg (deflated 9%)
#   adding: 658.jpg (deflated 9%)
#   adding: 700.jpg (deflated 9%)
#   adding: 481.jpg (deflated 9%)
#   adding: 114.jpg (deflated 9%)
#   adding: 209.jpg (deflated 8%)
#   adding: 365.jpg (deflated 8%)
#   adding: 717.jpg (deflated 8%)
#   adding: 354.jpg (deflated 10%)
#   adding: 825.jpg (deflated 9%)
#   adding: 684.jpg (deflated 8%)
#   adding: 791.jpg (deflated 9%)
#   adding: 151.jpg (deflated 8%)
#   adding: 169.jpg (deflated 9%)
#   adding: 707.jpg (deflated 11%)
#   adding: 467.jpg (deflated 8%)
#   adding: 148.jpg (deflated 9%)
#   adding: 944.jpg (deflated 10%)
#   adding: 538.jpg (deflated 9%)
#   adding: 190.jpg (deflated 9%)
#   adding: 864.jpg (deflated 8%)
#   adding: 908.jpg (deflated 10%)
#   adding: 432.jpg (deflated 12%)
#   adding: 164.jpg (deflated 7%)
#   adding: 750.jpg (deflated 9%)
#   adding: 955.jpg (deflated 8%)
#   adding: 774.jpg (deflated 8%)
#   adding: 14.jpg (deflated 9%)
#   adding: 181.jpg (deflated 9%)
#   adding: 662.jpg (deflated 9%)
#   adding: 434.jpg (deflated 9%)
#   adding: 35.jpg (deflated 10%)
#   adding: 733.jpg (deflated 7%)
#   adding: 10.jpg (deflated 10%)
#   adding: 735.jpg (deflated 8%)
#   adding: 466.jpg (deflated 9%)
#   adding: 530.jpg (deflated 8%)
#   adding: 505.jpg (deflated 9%)
#   adding: 784.jpg (deflated 9%)
#   adding: 703.jpg (deflated 8%)
#   adding: 189.jpg (deflated 8%)
#   adding: 204.jpg (deflated 9%)
#   adding: 909.jpg (deflated 9%)
#   adding: 830.jpg (deflated 11%)
#   adding: 311.jpg (deflated 9%)
#   adding: 645.jpg (deflated 9%)
#   adding: 405.jpg (deflated 9%)
#   adding: 24.jpg (deflated 8%)
#   adding: 649.jpg (deflated 9%)
#   adding: 254.jpg (deflated 9%)
#   adding: 226.jpg (deflated 9%)
#   adding: 946.jpg (deflated 9%)
#   adding: 953.jpg (deflated 8%)
#   adding: 395.jpg (deflated 8%)
#   adding: 943.jpg (deflated 9%)
#   adding: 333.jpg (deflated 9%)
#   adding: 940.jpg (deflated 8%)
#   adding: 445.jpg (deflated 8%)
#   adding: 157.jpg (deflated 9%)
#   adding: 188.jpg (deflated 9%)
#   adding: 674.jpg (deflated 9%)
#   adding: 810.jpg (deflated 9%)
#   adding: 358.jpg (deflated 10%)
#   adding: 175.jpg (deflated 9%)
#   adding: 142.jpg (deflated 9%)
#   adding: 587.jpg (deflated 9%)
#   adding: 606.jpg (deflated 8%)
#   adding: 349.jpg (deflated 9%)
#   adding: 369.jpg (deflated 10%)
#   adding: 318.jpg (deflated 9%)
#   adding: 883.jpg (deflated 9%)
#   adding: 720.jpg (deflated 7%)
#   adding: 162.jpg (deflated 8%)
#   adding: 892.jpg (deflated 9%)
#   adding: 925.jpg (deflated 9%)
#   adding: 396.jpg (deflated 8%)
#   adding: 638.jpg (deflated 10%)
#   adding: 80.jpg (deflated 8%)
#   adding: 678.jpg (deflated 8%)
#   adding: 107.jpg (deflated 9%)
#   adding: 364.jpg (deflated 9%)
#   adding: 177.jpg (deflated 9%)
#   adding: 108.jpg (deflated 8%)
#   adding: 889.jpg (deflated 9%)
#   adding: 91.jpg (deflated 8%)
#   adding: 693.jpg (deflated 7%)
#   adding: 775.jpg (deflated 10%)
#   adding: 601.jpg (deflated 9%)
#   adding: 962.jpg (deflated 9%)
#   adding: 629.jpg (deflated 10%)
#   adding: 494.jpg (deflated 10%)
#   adding: 690.jpg (deflated 11%)
#   adding: 806.jpg (deflated 9%)
#   adding: 592.jpg (deflated 9%)
#   adding: 321.jpg (deflated 8%)
#   adding: 116.jpg (deflated 8%)
#   adding: 852.jpg (deflated 8%)
#   adding: 307.jpg (deflated 9%)
#   adding: 832.jpg (deflated 8%)
#   adding: 828.jpg (deflated 10%)
#   adding: 769.jpg (deflated 8%)
#   adding: 840.jpg (deflated 8%)
#   adding: 200.jpg (deflated 9%)
#   adding: 191.jpg (deflated 9%)
#   adding: 786.jpg (deflated 9%)
#   adding: 334.jpg (deflated 9%)
#   adding: 3.jpg (deflated 9%)
#   adding: 710.jpg (deflated 9%)
#   adding: 235.jpg (deflated 7%)
#   adding: 313.jpg (deflated 8%)
#   adding: 776.jpg (deflated 9%)
#   adding: 589.jpg (deflated 8%)
#   adding: 112.jpg (deflated 9%)
#   adding: 478.jpg (deflated 8%)
#   adding: 265.jpg (deflated 8%)
#   adding: 256.jpg (deflated 9%)
#   adding: 716.jpg (deflated 8%)
#   adding: 351.jpg (deflated 9%)
#   adding: 837.jpg (deflated 9%)
#   adding: 208.jpg (deflated 9%)
#   adding: 914.jpg (deflated 8%)
#   adding: 582.jpg (deflated 9%)
#   adding: 873.jpg (deflated 8%)
#   adding: 433.jpg (deflated 9%)
#   adding: 202.jpg (deflated 8%)
#   adding: 423.jpg (deflated 8%)
#   adding: 803.jpg (deflated 10%)
#   adding: 492.jpg (deflated 8%)
#   adding: 932.jpg (deflated 9%)
#   adding: 21.jpg (deflated 9%)
#   adding: 93.jpg (deflated 9%)
#   adding: 536.jpg (deflated 8%)
#   adding: 37.jpg (deflated 11%)
#   adding: 489.jpg (deflated 9%)
#   adding: 81.jpg (deflated 9%)
#   adding: 817.jpg (deflated 9%)
#   adding: 97.jpg (deflated 7%)
#   adding: 56.jpg (deflated 9%)
#   adding: 755.jpg (deflated 8%)
#   adding: 843.jpg (deflated 8%)
#   adding: 327.jpg (deflated 9%)
#   adding: 780.jpg (deflated 9%)
#   adding: 197.jpg (deflated 9%)
#   adding: 721.jpg (deflated 9%)
#   adding: 611.jpg (deflated 8%)
#   adding: 390.jpg (deflated 8%)
#   adding: 73.jpg (deflated 9%)
#   adding: 225.jpg (deflated 8%)
#   adding: 671.jpg (deflated 8%)
#   adding: 109.jpg (deflated 10%)
#   adding: 683.jpg (deflated 9%)
#   adding: 477.jpg (deflated 9%)
#   adding: 967.jpg (deflated 9%)
#   adding: 571.jpg (deflated 9%)
#   adding: 549.jpg (deflated 9%)
#   adding: 196.jpg (deflated 9%)
#   adding: 277.jpg (deflated 9%)
#   adding: 795.jpg (deflated 9%)
#   adding: 154.jpg (deflated 9%)
#   adding: 449.jpg (deflated 8%)
#   adding: 736.jpg (deflated 8%)
#   adding: 8.jpg (deflated 9%)
#   adding: 771.jpg (deflated 10%)
#   adding: 290.jpg (deflated 9%)
#   adding: 871.jpg (deflated 9%)
#   adding: 71.jpg (deflated 9%)
#   adding: 807.jpg (deflated 10%)
#   adding: 918.jpg (deflated 9%)
#   adding: 644.jpg (deflated 9%)
#   adding: 344.jpg (deflated 9%)
#   adding: 319.jpg (deflated 8%)
#   adding: 903.jpg (deflated 9%)
#   adding: 630.jpg (deflated 8%)
#   adding: 465.jpg (deflated 9%)
#   adding: 306.jpg (deflated 10%)
#   adding: 989.jpg (deflated 8%)
#   adding: 667.jpg (deflated 8%)
#   adding: 219.jpg (deflated 10%)
#   adding: 801.jpg (deflated 9%)
#   adding: 926.jpg (deflated 8%)
#   adding: 499.jpg (deflated 10%)
#   adding: 332.jpg (deflated 9%)
#   adding: 756.jpg (deflated 10%)
#   adding: 619.jpg (deflated 9%)
#   adding: 902.jpg (deflated 10%)
#   adding: 294.jpg (deflated 9%)
#   adding: 833.jpg (deflated 9%)
#   adding: 61.jpg (deflated 8%)
#   adding: 5.jpg (deflated 10%)
#   adding: 443.jpg (deflated 8%)
#   adding: 374.jpg (deflated 9%)
#   adding: 844.jpg (deflated 8%)
#   adding: 558.jpg (deflated 9%)
#   adding: 618.jpg (deflated 10%)
#   adding: 868.jpg (deflated 9%)
#   adding: 121.jpg (deflated 8%)
#   adding: 514.jpg (deflated 10%)
#   adding: 792.jpg (deflated 9%)
#   adding: 384.jpg (deflated 9%)
#   adding: 315.jpg (deflated 9%)
#   adding: 201.jpg (deflated 9%)
#   adding: 377.jpg (deflated 9%)
#   adding: 84.jpg (deflated 9%)
#   adding: 242.jpg (deflated 9%)
#   adding: 304.jpg (deflated 9%)
#   adding: 331.jpg (deflated 10%)
#   adding: 474.jpg (deflated 8%)
#   adding: 378.jpg (deflated 8%)
#   adding: 705.jpg (deflated 9%)
#   adding: 11.jpg (deflated 9%)
#   adding: 639.jpg (deflated 9%)
#   adding: 40.jpg (deflated 8%)
#   adding: 751.jpg (deflated 8%)
#   adding: 858.jpg (deflated 9%)
#   adding: 855.jpg (deflated 10%)
#   adding: 269.jpg (deflated 10%)
#   adding: 818.jpg (deflated 9%)
#   adding: 508.jpg (deflated 8%)
#   adding: 316.jpg (deflated 8%)
#   adding: 895.jpg (deflated 11%)
#   adding: 661.jpg (deflated 7%)
#   adding: 275.jpg (deflated 9%)
#   adding: 57.jpg (deflated 9%)
#   adding: 897.jpg (deflated 8%)
#   adding: 252.jpg (deflated 8%)
#   adding: 912.jpg (deflated 9%)
#   adding: 1.jpg (deflated 8%)
#   adding: 729.jpg (deflated 10%)
#   adding: 869.jpg (deflated 9%)
#   adding: 699.jpg (deflated 9%)
#   adding: 126.jpg (deflated 10%)
#   adding: 738.jpg (deflated 8%)
#   adding: 870.jpg (deflated 8%)
#   adding: 534.jpg (deflated 9%)
#   adding: 370.jpg (deflated 9%)
#   adding: 198.jpg (deflated 8%)
#   adding: 568.jpg (deflated 9%)
#   adding: 419.jpg (deflated 9%)
#   adding: 412.jpg (deflated 8%)
#   adding: 663.jpg (deflated 10%)
#   adding: 215.jpg (deflated 9%)
#   adding: 659.jpg (deflated 9%)
#   adding: 854.jpg (deflated 9%)
#   adding: 754.jpg (deflated 9%)
#   adding: 588.jpg (deflated 9%)
#   adding: 237.jpg (deflated 10%)
#   adding: 66.jpg (deflated 9%)
#   adding: 569.jpg (deflated 9%)
#   adding: 782.jpg (deflated 9%)
#   adding: 994.jpg (deflated 9%)
#   adding: 406.jpg (deflated 9%)
#   adding: 594.jpg (deflated 8%)
#   adding: 182.jpg (deflated 9%)
#   adding: 915.jpg (deflated 8%)
#   adding: 411.jpg (deflated 10%)
#   adding: 655.jpg (deflated 8%)
#   adding: 501.jpg (deflated 8%)
#   adding: 356.jpg (deflated 8%)
#   adding: 128.jpg (deflated 9%)
#   adding: 961.jpg (deflated 9%)
#   adding: 831.jpg (deflated 10%)
#   adding: 581.jpg (deflated 8%)
#   adding: 230.jpg (deflated 10%)
#   adding: 599.jpg (deflated 8%)
#   adding: 394.jpg (deflated 9%)
#   adding: 194.jpg (deflated 9%)
#   adding: 672.jpg (deflated 10%)
#   adding: 184.jpg (deflated 8%)
#   adding: 303.jpg (deflated 9%)
#   adding: 195.jpg (deflated 8%)
#   adding: 986.jpg (deflated 8%)
#   adding: 753.jpg (deflated 8%)
#   adding: 78.jpg (deflated 9%)
#   adding: 359.jpg (deflated 9%)
#   adding: 763.jpg (deflated 9%)
#   adding: 719.jpg (deflated 9%)
#   adding: 498.jpg (deflated 8%)
#   adding: 512.jpg (deflated 10%)
#   adding: 660.jpg (deflated 8%)
#   adding: 983.jpg (deflated 10%)
#   adding: 238.jpg (deflated 9%)
#   adding: 798.jpg (deflated 8%)
#   adding: 224.jpg (deflated 9%)
#   adding: 790.jpg (deflated 9%)
#   adding: 881.jpg (deflated 9%)
#   adding: 628.jpg (deflated 9%)
#   adding: 531.jpg (deflated 7%)
#   adding: 680.jpg (deflated 8%)
#   adding: 981.jpg (deflated 9%)
#   adding: 289.jpg (deflated 10%)
#   adding: 591.jpg (deflated 9%)
#   adding: 174.jpg (deflated 9%)
#   adding: 456.jpg (deflated 9%)
#   adding: 627.jpg (deflated 9%)
#   adding: 245.jpg (deflated 8%)
#   adding: 506.jpg (deflated 9%)
#   adding: 163.jpg (deflated 9%)
#   adding: 884.jpg (deflated 9%)
#   adding: 422.jpg (deflated 9%)
#   adding: 233.jpg (deflated 9%)
#   adding: 566.jpg (deflated 10%)
#   adding: 431.jpg (deflated 8%)
#   adding: 248.jpg (deflated 10%)
#   adding: 562.jpg (deflated 8%)
#   adding: 894.jpg (deflated 9%)
#   adding: 636.jpg (deflated 7%)
#   adding: 813.jpg (deflated 9%)
#   adding: 850.jpg (deflated 9%)
#   adding: 835.jpg (deflated 8%)
#   adding: 447.jpg (deflated 9%)
#   adding: 827.jpg (deflated 8%)
#   adding: 739.jpg (deflated 9%)
#   adding: 676.jpg (deflated 10%)
#   adding: 68.jpg (deflated 8%)
#   adding: 302.jpg (deflated 8%)
#   adding: 758.jpg (deflated 9%)
#   adding: 971.jpg (deflated 9%)
#   adding: 106.jpg (deflated 9%)
#   adding: 379.jpg (deflated 9%)
#   adding: 476.jpg (deflated 8%)
#   adding: 802.jpg (deflated 9%)
#   adding: 609.jpg (deflated 9%)
#   adding: 669.jpg (deflated 7%)
#   adding: 439.jpg (deflated 8%)
#   adding: 626.jpg (deflated 9%)
#   adding: 548.jpg (deflated 10%)
#   adding: 876.jpg (deflated 10%)
#   adding: 759.jpg (deflated 10%)
#   adding: 877.jpg (deflated 10%)
#   adding: 916.jpg (deflated 9%)
#   adding: 826.jpg (deflated 7%)
#   adding: 741.jpg (deflated 9%)
#   adding: 593.jpg (deflated 9%)
#   adding: 765.jpg (deflated 8%)
#   adding: 585.jpg (deflated 9%)
#   adding: 689.jpg (deflated 8%)
#   adding: 685.jpg (deflated 8%)
#   adding: 96.jpg (deflated 8%)
#   adding: 100.jpg (deflated 9%)
#   adding: 393.jpg (deflated 9%)
#   adding: 99.jpg (deflated 8%)
#   adding: 706.jpg (deflated 9%)
#   adding: 205.jpg (deflated 9%)
#   adding: 389.jpg (deflated 11%)
#   adding: 632.jpg (deflated 9%)
#   adding: 166.jpg (deflated 9%)
#   adding: 22.jpg (deflated 9%)
#   adding: 642.jpg (deflated 9%)
#   adding: 845.jpg (deflated 9%)
#   adding: 258.jpg (deflated 9%)
#   adding: 20.jpg (deflated 10%)
#   adding: 282.jpg (deflated 10%)
#   adding: 440.jpg (deflated 8%)
#   adding: 310.jpg (deflated 9%)
#   adding: 137.jpg (deflated 9%)
#   adding: 361.jpg (deflated 9%)
#   adding: 513.jpg (deflated 9%)
#   adding: 102.jpg (deflated 9%)
#   adding: 793.jpg (deflated 9%)
#   adding: 829.jpg (deflated 8%)
#   adding: 227.jpg (deflated 9%)
#   adding: 328.jpg (deflated 8%)
#   adding: 110.jpg (deflated 8%)
#   adding: 878.jpg (deflated 11%)
#   adding: 687.jpg (deflated 9%)
#   adding: 493.jpg (deflated 9%)
#   adding: 491.jpg (deflated 9%)
#   adding: 427.jpg (deflated 9%)
#   adding: 526.jpg (deflated 8%)
#   adding: 504.jpg (deflated 9%)
#   adding: 728.jpg (deflated 9%)
#   adding: 885.jpg (deflated 9%)
#   adding: 906.jpg (deflated 9%)
#   adding: 470.jpg (deflated 9%)
#   adding: 210.jpg (deflated 11%)
#   adding: 480.jpg (deflated 9%)
#   adding: 31.jpg (deflated 9%)
#   adding: 101.jpg (deflated 7%)
#   adding: 653.jpg (deflated 8%)
#   adding: 193.jpg (deflated 9%)
#   adding: 308.jpg (deflated 9%)
#   adding: 436.jpg (deflated 12%)
#   adding: 352.jpg (deflated 8%)
#   adding: 314.jpg (deflated 9%)
#   adding: 95.jpg (deflated 9%)
#   adding: 507.jpg (deflated 9%)
#   adding: 490.jpg (deflated 8%)
#   adding: 15.jpg (deflated 8%)
#   adding: 266.jpg (deflated 8%)
#   adding: 646.jpg (deflated 9%)
#   adding: 392.jpg (deflated 8%)
#   adding: 408.jpg (deflated 11%)
#   adding: 165.jpg (deflated 10%)
#   adding: 259.jpg (deflated 9%)
#   adding: 637.jpg (deflated 9%)
#   adding: 388.jpg (deflated 9%)
#   adding: 596.jpg (deflated 8%)
#   adding: 203.jpg (deflated 8%)
#   adding: 921.jpg (deflated 9%)
#   adding: 931.jpg (deflated 7%)
#   adding: 997.jpg (deflated 8%)
#   adding: 634.jpg (deflated 9%)
#   adding: 907.jpg (deflated 9%)
#   adding: 32.jpg (deflated 9%)
#   adding: 718.jpg (deflated 8%)
#   adding: 614.jpg (deflated 9%)
#   adding: 656.jpg (deflated 9%)
#   adding: 613.jpg (deflated 10%)
#   adding: 2.jpg (deflated 9%)
#   adding: 473.jpg (deflated 9%)
#   adding: 580.jpg (deflated 10%)
#   adding: 527.jpg (deflated 9%)
#   adding: 510.jpg (deflated 9%)
#   adding: 808.jpg (deflated 9%)
#   adding: 712.jpg (deflated 9%)
#   adding: 898.jpg (deflated 8%)
#   adding: 734.jpg (deflated 8%)
#   adding: 485.jpg (deflated 9%)
#   adding: 732.jpg (deflated 9%)
#   adding: 772.jpg (deflated 8%)
#   adding: 575.jpg (deflated 9%)
#   adding: 938.jpg (deflated 8%)
#   adding: 972.jpg (deflated 8%)
#   adding: 778.jpg (deflated 9%)
#   adding: 213.jpg (deflated 9%)
#   adding: 286.jpg (deflated 8%)
#   adding: 624.jpg (deflated 8%)
#   adding: 170.jpg (deflated 8%)
#   adding: 875.jpg (deflated 9%)
#   adding: 167.jpg (deflated 7%)
#   adding: 391.jpg (deflated 8%)
#   adding: 905.jpg (deflated 8%)
#   adding: 517.jpg (deflated 8%)
#   adding: 462.jpg (deflated 9%)
#   adding: 497.jpg (deflated 10%)
#   adding: 371.jpg (deflated 9%)
#   adding: 155.jpg (deflated 9%)
#   adding: 484.jpg (deflated 9%)
#   adding: 848.jpg (deflated 10%)
#   adding: 26.jpg (deflated 8%)
#   adding: 928.jpg (deflated 9%)
#   adding: 52.jpg (deflated 9%)
#   adding: 287.jpg (deflated 8%)
#   adding: 136.jpg (deflated 9%)
#   adding: 701.jpg (deflated 8%)
#   adding: 923.jpg (deflated 9%)
#   adding: 586.jpg (deflated 8%)
#   adding: 648.jpg (deflated 9%)
#   adding: 600.jpg (deflated 8%)
#   adding: 133.jpg (deflated 8%)
#   adding: 615.jpg (deflated 9%)
#   adding: 454.jpg (deflated 10%)
#   adding: 262.jpg (deflated 9%)
#   adding: 856.jpg (deflated 9%)
#   adding: 917.jpg (deflated 8%)
#   adding: 487.jpg (deflated 9%)
#   adding: 745.jpg (deflated 8%)
#   adding: 535.jpg (deflated 10%)
#   adding: 709.jpg (deflated 8%)
#   adding: 788.jpg (deflated 8%)
#   adding: 221.jpg (deflated 9%)
#   adding: 605.jpg (deflated 9%)
#   adding: 509.jpg (deflated 10%)
#   adding: 382.jpg (deflated 9%)
#   adding: 964.jpg (deflated 9%)
#   adding: 111.jpg (deflated 8%)
#   adding: 610.jpg (deflated 9%)
#   adding: 83.jpg (deflated 10%)
#   adding: 231.jpg (deflated 11%)
#   adding: 131.jpg (deflated 9%)
#   adding: 541.jpg (deflated 7%)
#   adding: 939.jpg (deflated 9%)
#   adding: 452.jpg (deflated 9%)
#   adding: 572.jpg (deflated 10%)
#   adding: 58.jpg (deflated 8%)
#   adding: 708.jpg (deflated 8%)
#   adding: 468.jpg (deflated 9%)
#   adding: 291.jpg (deflated 8%)
#   adding: 887.jpg (deflated 8%)
#   adding: 463.jpg (deflated 8%)
#   adding: 816.jpg (deflated 9%)
#   adding: 281.jpg (deflated 9%)
#   adding: 554.jpg (deflated 8%)
#   adding: 385.jpg (deflated 9%)
#   adding: 651.jpg (deflated 8%)
#   adding: 727.jpg (deflated 9%)
#   adding: 366.jpg (deflated 9%)
#   adding: 244.jpg (deflated 8%)
#   adding: 934.jpg (deflated 8%)
#   adding: 267.jpg (deflated 9%)
#   adding: 942.jpg (deflated 9%)
#   adding: 132.jpg (deflated 10%)
#   adding: 975.jpg (deflated 9%)
#   adding: 901.jpg (deflated 9%)
#   adding: 993.jpg (deflated 8%)
#   adding: 973.jpg (deflated 8%)
#   adding: 70.jpg (deflated 11%)
#   adding: 988.jpg (deflated 9%)
#   adding: 236.jpg (deflated 11%)
#   adding: 849.jpg (deflated 9%)
#   adding: 985.jpg (deflated 9%)
#   adding: 888.jpg (deflated 9%)
#   adding: 38.jpg (deflated 8%)
#   adding: 682.jpg (deflated 7%)
#   adding: 979.jpg (deflated 8%)
#   adding: 913.jpg (deflated 9%)
#   adding: 437.jpg (deflated 11%)
#   adding: 785.jpg (deflated 8%)
#   adding: 841.jpg (deflated 7%)
#   adding: 583.jpg (deflated 9%)
#   adding: 460.jpg (deflated 8%)
#   adding: 180.jpg (deflated 9%)
#   adding: 4.jpg (deflated 9%)
#   adding: 797.jpg (deflated 8%)
#   adding: 348.jpg (deflated 9%)
#   adding: 127.jpg (deflated 9%)
#   adding: 521.jpg (deflated 8%)
#   adding: 695.jpg (deflated 8%)
#   adding: 641.jpg (deflated 9%)
#   adding: 51.jpg (deflated 10%)
#   adding: 794.jpg (deflated 8%)
#   adding: 7.jpg (deflated 9%)
#   adding: 525.jpg (deflated 8%)
#   adding: 409.jpg (deflated 10%)
#   adding: 141.jpg (deflated 9%)
#   adding: 69.jpg (deflated 10%)
#   adding: 866.jpg (deflated 9%)
#   adding: 401.jpg (deflated 9%)
#   adding: 176.jpg (deflated 10%)
#   adding: 86.jpg (deflated 9%)
#   adding: 936.jpg (deflated 8%)
#   adding: 723.jpg (deflated 11%)
#   adding: 297.jpg (deflated 9%)
#   adding: 603.jpg (deflated 9%)
#   adding: 199.jpg (deflated 9%)
#   adding: 891.jpg (deflated 9%)
#   adding: 402.jpg (deflated 9%)
#   adding: 893.jpg (deflated 11%)
#   adding: 643.jpg (deflated 8%)
#   adding: 85.jpg (deflated 7%)
#   adding: 119.jpg (deflated 8%)
#   adding: 577.jpg (deflated 9%)
#   adding: 984.jpg (deflated 10%)
#   adding: 773.jpg (deflated 7%)
#   adding: 524.jpg (deflated 8%)
#   adding: 515.jpg (deflated 7%)
#   adding: 372.jpg (deflated 8%)
#   adding: 564.jpg (deflated 12%)
#   adding: 584.jpg (deflated 11%)
#   adding: 670.jpg (deflated 8%)
#   adding: 617.jpg (deflated 10%)
#   adding: 823.jpg (deflated 9%)
#   adding: 243.jpg (deflated 9%)
#   adding: 239.jpg (deflated 9%)
#   adding: 347.jpg (deflated 9%)
#   adding: 865.jpg (deflated 9%)
#   adding: 152.jpg (deflated 10%)
#   adding: 595.jpg (deflated 8%)
#   adding: 805.jpg (deflated 9%)
#   adding: 295.jpg (deflated 7%)
#   adding: 280.jpg (deflated 9%)
#   adding: 350.jpg (deflated 8%)
#   adding: 948.jpg (deflated 8%)
#   adding: 337.jpg (deflated 8%)
#   adding: 764.jpg (deflated 8%)
#   adding: 711.jpg (deflated 10%)
#   adding: 441.jpg (deflated 8%)
#   adding: 363.jpg (deflated 9%)
#   adding: 410.jpg (deflated 9%)
#   adding: 537.jpg (deflated 9%)
#   adding: 781.jpg (deflated 10%)
#   adding: 160.jpg (deflated 11%)
#   adding: 178.jpg (deflated 7%)
#   adding: 838.jpg (deflated 9%)
#   adding: 25.jpg (deflated 9%)
#   adding: 930.jpg (deflated 10%)
#   adding: 346.jpg (deflated 9%)
#   adding: 495.jpg (deflated 8%)
#   adding: 42.jpg (deflated 9%)
#   adding: 851.jpg (deflated 9%)
#   adding: 417.jpg (deflated 10%)
#   adding: 438.jpg (deflated 9%)
#   adding: 872.jpg (deflated 9%)
#   adding: 403.jpg (deflated 9%)
#   adding: 118.jpg (deflated 8%)
#   adding: 664.jpg (deflated 9%)
#   adding: 338.jpg (deflated 9%)
#   adding: 218.jpg (deflated 9%)
#   adding: 173.jpg (deflated 9%)
#   adding: 404.jpg (deflated 9%)
#   adding: 560.jpg (deflated 9%)
#   adding: 519.jpg (deflated 8%)
#   adding: 991.jpg (deflated 9%)
#   adding: 815.jpg (deflated 10%)
#   adding: 323.jpg (deflated 9%)
#   adding: 186.jpg (deflated 9%)
#   adding: 551.jpg (deflated 8%)
#   adding: 125.jpg (deflated 9%)
#   adding: 130.jpg (deflated 9%)
#   adding: 246.jpg (deflated 9%)
#   adding: 255.jpg (deflated 9%)
#   adding: 598.jpg (deflated 8%)
#   adding: 937.jpg (deflated 9%)
#   adding: 450.jpg (deflated 8%)
#   adding: 140.jpg (deflated 9%)
#   adding: 528.jpg (deflated 9%)
#   adding: 799.jpg (deflated 10%)
#   adding: 399.jpg (deflated 7%)
#   adding: 836.jpg (deflated 10%)
#   adding: 824.jpg (deflated 9%)
#   adding: 502.jpg (deflated 9%)
#   adding: 623.jpg (deflated 9%)
#   adding: 92.jpg (deflated 8%)
#   adding: 216.jpg (deflated 9%)
#   adding: 579.jpg (deflated 9%)
#   adding: 976.jpg (deflated 9%)
#   adding: 546.jpg (deflated 10%)
#   adding: 217.jpg (deflated 9%)
#   adding: 232.jpg (deflated 10%)
#   adding: 115.jpg (deflated 8%)
#   adding: 974.jpg (deflated 9%)
#   adding: 455.jpg (deflated 8%)
#   adding: 879.jpg (deflated 9%)
#   adding: 144.jpg (deflated 8%)
#   adding: 625.jpg (deflated 8%)
#   adding: 373.jpg (deflated 9%)
#   adding: 978.jpg (deflated 8%)
#   adding: 714.jpg (deflated 9%)
#   adding: 134.jpg (deflated 11%)
#   adding: 104.jpg (deflated 8%)
#   adding: 464.jpg (deflated 9%)
#   adding: 94.jpg (deflated 10%)
#   adding: 446.jpg (deflated 9%)
#   adding: 927.jpg (deflated 10%)
#   adding: 996.jpg (deflated 9%)
#   adding: 557.jpg (deflated 9%)
#   adding: 120.jpg (deflated 9%)
#   adding: 965.jpg (deflated 9%)
#   adding: 821.jpg (deflated 8%)
#   adding: 357.jpg (deflated 8%)
#   adding: 576.jpg (deflated 9%)
#   adding: 229.jpg (deflated 8%)
#   adding: 276.jpg (deflated 10%)
#   adding: 145.jpg (deflated 8%)
#   adding: 814.jpg (deflated 8%)
#   adding: 998.jpg (deflated 10%)
#   adding: 523.jpg (deflated 7%)
#   adding: 621.jpg (deflated 8%)
#   adding: 376.jpg (deflated 8%)
#   adding: 853.jpg (deflated 9%)
#   adding: 64.jpg (deflated 10%)
#   adding: 27.jpg (deflated 10%)
#   adding: 355.jpg (deflated 8%)
#   adding: 935.jpg (deflated 9%)
#   adding: 362.jpg (deflated 9%)
#   adding: 631.jpg (deflated 9%)
#   adding: 696.jpg (deflated 8%)
#   adding: 322.jpg (deflated 8%)
#   adding: 652.jpg (deflated 9%)
#   adding: 150.jpg (deflated 8%)
#   adding: 260.jpg (deflated 8%)
#   adding: 414.jpg (deflated 10%)
#   adding: 143.jpg (deflated 11%)
#   adding: 511.jpg (deflated 9%)
#   adding: 234.jpg (deflated 9%)
#   adding: 635.jpg (deflated 8%)
#   adding: 666.jpg (deflated 8%)
#   adding: 725.jpg (deflated 8%)
#   adding: 867.jpg (deflated 8%)
#   adding: 686.jpg (deflated 9%)
#   adding: 622.jpg (deflated 8%)
#   adding: 187.jpg (deflated 9%)
#   adding: 688.jpg (deflated 9%)
#   adding: 789.jpg (deflated 10%)
#   adding: 257.jpg (deflated 8%)
#   adding: 896.jpg (deflated 8%)
#   adding: 340.jpg (deflated 9%)
#   adding: 211.jpg (deflated 8%)
#   adding: 616.jpg (deflated 8%)
#   adding: 430.jpg (deflated 7%)
#   adding: 183.jpg (deflated 9%)
#   adding: 834.jpg (deflated 9%)
#   adding: 153.jpg (deflated 9%)
#   adding: 17.jpg (deflated 9%)
#   adding: 168.jpg (deflated 9%)
#   adding: 74.jpg (deflated 10%)
#   adding: 812.jpg (deflated 10%)
#   adding: 16.jpg (deflated 9%)
#   adding: 105.jpg (deflated 9%)
#   adding: 752.jpg (deflated 10%)
#   adding: 941.jpg (deflated 9%)
#   adding: 578.jpg (deflated 9%)
#   adding: 54.jpg (deflated 9%)
#   adding: 368.jpg (deflated 9%)
#   adding: 543.jpg (deflated 8%)
#   adding: 563.jpg (deflated 10%)
#   adding: 381.jpg (deflated 9%)
#   adding: 570.jpg (deflated 9%)
#   adding: 299.jpg (deflated 7%)
#   adding: 969.jpg (deflated 10%)
#   adding: 475.jpg (deflated 11%)
#   adding: 922.jpg (deflated 9%)
#   adding: 742.jpg (deflated 10%)
#   adding: 677.jpg (deflated 8%)
#   adding: 533.jpg (deflated 8%)
#   adding: 342.jpg (deflated 7%)
#   adding: 13.jpg (deflated 9%)
#   adding: 691.jpg (deflated 8%)
#   adding: 268.jpg (deflated 9%)
#   adding: 679.jpg (deflated 10%)
#   adding: 486.jpg (deflated 8%)
#   adding: 158.jpg (deflated 8%)
#   adding: 76.jpg (deflated 9%)
#   adding: 518.jpg (deflated 9%)
#   adding: 421.jpg (deflated 9%)
#   adding: 343.jpg (deflated 9%)
#   adding: 958.jpg (deflated 9%)
#   adding: 768.jpg (deflated 8%)
#   adding: 900.jpg (deflated 9%)
#   adding: 123.jpg (deflated 10%)
#   adding: 341.jpg (deflated 10%)
#   adding: 726.jpg (deflated 8%)
#   adding: 777.jpg (deflated 9%)
#   adding: 552.jpg (deflated 9%)
#   adding: 770.jpg (deflated 10%)
#   adding: 117.jpg (deflated 8%)
#   adding: 597.jpg (deflated 9%)
#   adding: 312.jpg (deflated 10%)
#   adding: 839.jpg (deflated 9%)
#   adding: 740.jpg (deflated 9%)
#   adding: 220.jpg (deflated 12%)
#   adding: 207.jpg (deflated 10%)
#   adding: 947.jpg (deflated 8%)
#   adding: 270.jpg (deflated 9%)
#   adding: 305.jpg (deflated 9%)
#   adding: 67.jpg (deflated 9%)
#   adding: 565.jpg (deflated 9%)
#   adding: 48.jpg (deflated 9%)
#   adding: 471.jpg (deflated 10%)
#   adding: 263.jpg (deflated 8%)
#   adding: 890.jpg (deflated 9%)
#   adding: 950.jpg (deflated 9%)
#   adding: 43.jpg (deflated 9%)
#   adding: 1000.jpg (deflated 9%)
#   adding: 529.jpg (deflated 9%)
#   adding: 212.jpg (deflated 8%)
#   adding: 767.jpg (deflated 8%)
#   adding: 874.jpg (deflated 8%)
#   adding: 18.jpg (deflated 9%)
#   adding: 360.jpg (deflated 11%)
#   adding: 296.jpg (deflated 8%)
#   adding: 980.jpg (deflated 7%)
#   adding: 36.jpg (deflated 9%)
#   adding: 214.jpg (deflated 9%)
#   adding: 811.jpg (deflated 8%)
#   adding: 694.jpg (deflated 10%)
#   adding: 692.jpg (deflated 9%)
#   adding: 124.jpg (deflated 10%)
#   adding: 407.jpg (deflated 8%)
#   adding: 320.jpg (deflated 8%)
#   adding: 461.jpg (deflated 10%)
#   adding: 604.jpg (deflated 9%)
#   adding: 55.jpg (deflated 8%)
#   adding: 555.jpg (deflated 8%)
#   adding: 766.jpg (deflated 9%)
#   adding: 886.jpg (deflated 9%)
#   adding: 966.jpg (deflated 8%)
#   adding: 429.jpg (deflated 8%)
#   adding: 228.jpg (deflated 8%)
#   adding: 846.jpg (deflated 9%)
#   adding: 317.jpg (deflated 9%)
#   adding: 488.jpg (deflated 8%)
#   adding: 147.jpg (deflated 10%)
#   adding: 472.jpg (deflated 8%)
#   adding: 426.jpg (deflated 7%)
#   adding: 731.jpg (deflated 8%)
#   adding: 416.jpg (deflated 8%)
#   adding: 724.jpg (deflated 9%)
#   adding: 59.jpg (deflated 9%)
#   adding: 746.jpg (deflated 10%)
#   adding: 863.jpg (deflated 9%)
#   adding: 761.jpg (deflated 10%)
#   adding: 880.jpg (deflated 7%)
#   adding: 30.jpg (deflated 9%)
#   adding: 75.jpg (deflated 10%)
#   adding: 90.jpg (deflated 9%)
#   adding: 47.jpg (deflated 9%)
#   adding: 963.jpg (deflated 8%)
#   adding: 300.jpg (deflated 7%)
#   adding: 483.jpg (deflated 8%)
#   adding: 749.jpg (deflated 9%)
#   adding: 516.jpg (deflated 9%)
#   adding: 122.jpg (deflated 9%)
#   adding: 697.jpg (deflated 8%)
#   adding: 79.jpg (deflated 10%)
#   adding: 98.jpg (deflated 8%)
#   adding: 787.jpg (deflated 11%)
#   adding: 503.jpg (deflated 8%)
#   adding: 532.jpg (deflated 9%)
#   adding: 945.jpg (deflated 8%)
#   adding: 172.jpg (deflated 8%)
#   adding: 612.jpg (deflated 7%)
#   adding: 820.jpg (deflated 8%)
#   adding: 559.jpg (deflated 9%)
#   adding: 479.jpg (deflated 9%)
#   adding: 283.jpg (deflated 9%)
#   adding: 809.jpg (deflated 8%)
#   adding: 545.jpg (deflated 8%)
#   adding: 415.jpg (deflated 9%)
#   adding: 757.jpg (deflated 8%)
#   adding: 668.jpg (deflated 9%)
#   adding: 82.jpg (deflated 9%)
#   adding: 41.jpg (deflated 9%)
#   adding: 113.jpg (deflated 9%)
#   adding: 722.jpg (deflated 8%)
#   adding: 550.jpg (deflated 8%)
#   adding: 951.jpg (deflated 9%)
#   adding: 274.jpg (deflated 9%)
#   adding: 206.jpg (deflated 9%)
#   adding: 910.jpg (deflated 8%)
#   adding: 185.jpg (deflated 9%)
#   adding: 542.jpg (deflated 9%)
#   adding: 842.jpg (deflated 8%)
#   adding: 223.jpg (deflated 9%)
#   adding: 28.jpg (deflated 8%)
#   adding: 309.jpg (deflated 8%)
#   adding: 9.jpg (deflated 9%)
#   adding: 899.jpg (deflated 8%)
#   adding: 424.jpg (deflated 7%)
#   adding: 999.jpg (deflated 8%)
#   adding: 657.jpg (deflated 9%)
#   adding: 222.jpg (deflated 9%)
#   adding: 783.jpg (deflated 11%)
#   adding: 760.jpg (deflated 9%)
#   adding: 459.jpg (deflated 13%)
#   adding: 46.jpg (deflated 9%)
#   adding: 345.jpg (deflated 9%)
#   adding: 72.jpg (deflated 8%)
#   adding: 12.jpg (deflated 9%)
#   adding: 29.jpg (deflated 8%)
#   adding: 240.jpg (deflated 9%)
#   adding: 251.jpg (deflated 8%)
#   adding: 457.jpg (deflated 8%)
#   adding: 573.jpg (deflated 9%)
#   adding: 747.jpg (deflated 7%)
#   adding: 574.jpg (deflated 8%)
#   adding: 241.jpg (deflated 9%)
#   adding: 330.jpg (deflated 10%)
#   adding: 23.jpg (deflated 9%)
#   adding: 273.jpg (deflated 10%)
#   adding: 129.jpg (deflated 8%)
#   adding: 702.jpg (deflated 9%)
#   adding: 743.jpg (deflated 10%)
#   adding: 192.jpg (deflated 9%)
#   adding: 272.jpg (deflated 8%)
#   adding: 387.jpg (deflated 11%)
#   adding: 247.jpg (deflated 9%)
#   adding: 149.jpg (deflated 9%)
#   adding: 138.jpg (deflated 9%)
#   adding: 65.jpg (deflated 8%)
#   adding: 6.jpg (deflated 10%)
#   adding: 451.jpg (deflated 8%)
#   adding: 933.jpg (deflated 9%)
#   adding: 448.jpg (deflated 9%)
#   adding: 442.jpg (deflated 9%)
#   adding: 847.jpg (deflated 10%)
#   adding: 375.jpg (deflated 8%)
#   adding: 253.jpg (deflated 9%)
#   adding: 970.jpg (deflated 8%)
#   adding: 418.jpg (deflated 9%)
#   adding: 620.jpg (deflated 8%)
#   adding: 50.jpg (deflated 9%)
#   adding: 88.jpg (deflated 8%)
#   adding: 326.jpg (deflated 9%)
#   adding: 640.jpg (deflated 10%)
#   adding: 929.jpg (deflated 9%)
#   adding: 602.jpg (deflated 9%)
#   adding: 353.jpg (deflated 9%)
#   adding: 633.jpg (deflated 8%)
#   adding: 397.jpg (deflated 10%)
#   adding: 386.jpg (deflated 8%)
#   adding: 713.jpg (deflated 8%)
#   adding: 288.jpg (deflated 8%)
#   adding: 156.jpg (deflated 8%)
#   adding: 919.jpg (deflated 9%)
#   adding: 567.jpg (deflated 7%)
#   adding: 957.jpg (deflated 9%)
#   adding: 329.jpg (deflated 8%)
#   adding: 704.jpg (deflated 9%)
#   adding: 444.jpg (deflated 9%)
#   adding: 748.jpg (deflated 9%)
#   adding: 911.jpg (deflated 9%)
#   adding: 608.jpg (deflated 8%)
#   adding: 681.jpg (deflated 9%)
#   adding: 336.jpg (deflated 9%)
#   adding: 367.jpg (deflated 8%)
#   adding: 590.jpg (deflated 9%)
#   adding: 469.jpg (deflated 9%)
#   adding: 796.jpg (deflated 9%)
#   adding: 544.jpg (deflated 9%)
#   adding: 673.jpg (deflated 10%)
#   adding: 285.jpg (deflated 9%)
#   adding: 293.jpg (deflated 8%)
#   adding: 53.jpg (deflated 10%)
#   adding: 607.jpg (deflated 8%)
#   adding: 804.jpg (deflated 9%)
#   adding: 482.jpg (deflated 9%)
#   adding: 822.jpg (deflated 8%)
#   adding: 520.jpg (deflated 9%)
#   adding: 959.jpg (deflated 9%)
#   adding: 62.jpg (deflated 8%)
#   adding: 860.jpg (deflated 8%)
#   adding: 956.jpg (deflated 9%)
#   adding: 335.jpg (deflated 9%)
#   adding: 977.jpg (deflated 9%)
#   adding: 284.jpg (deflated 8%)
#   adding: 800.jpg (deflated 9%)
#   adding: 159.jpg (deflated 9%)
#   adding: 698.jpg (deflated 9%)
#   adding: 715.jpg (deflated 9%)
#   adding: 139.jpg (deflated 9%)
#   adding: 135.jpg (deflated 9%)
#   adding: 954.jpg (deflated 8%)
#   adding: 982.jpg (deflated 9%)
#   adding: 882.jpg (deflated 8%)
#   adding: 19.jpg (deflated 9%)
#   adding: 279.jpg (deflated 9%)
#   adding: 271.jpg (deflated 9%)
#   adding: 278.jpg (deflated 8%)
#   adding: 398.jpg (deflated 9%)
#   adding: 325.jpg (deflated 9%)
#   adding: 779.jpg (deflated 9%)
#   adding: 819.jpg (deflated 9%)
#   adding: 665.jpg (deflated 8%)
#   adding: 992.jpg (deflated 8%)
#   adding: 675.jpg (deflated 7%)
#   adding: 924.jpg (deflated 8%)
#   adding: 264.jpg (deflated 8%)
#   adding: 762.jpg (deflated 8%)
#   adding: 261.jpg (deflated 8%)
#   adding: 33.jpg (deflated 9%)
#   adding: 428.jpg (deflated 9%)
#   adding: 453.jpg (deflated 10%)
#   adding: 435.jpg (deflated 13%)
#   adding: 857.jpg (deflated 8%)
#   adding: 60.jpg (deflated 9%)
#   adding: 250.jpg (deflated 9%)
#   adding: 179.jpg (deflated 10%)
#   adding: 861.jpg (deflated 9%)
#   adding: 949.jpg (deflated 8%)
#   adding: 990.jpg (deflated 10%)
#   adding: 380.jpg (deflated 9%)
#   adding: 987.jpg (deflated 10%)
#   adding: 522.jpg (deflated 8%)
#   adding: 413.jpg (deflated 8%)
#   adding: 425.jpg (deflated 8%)
#   adding: 298.jpg (deflated 8%)
#   adding: 383.jpg (deflated 8%)
#   adding: 540.jpg (deflated 9%)
#   adding: 561.jpg (deflated 9%)
#   adding: 161.jpg (deflated 9%)
#   adding: 420.jpg (deflated 9%)
#   adding: 960.jpg (deflated 9%)
#   adding: 496.jpg (deflated 9%)
#   adding: 862.jpg (deflated 8%)
#   adding: 89.jpg (deflated 8%)
#   adding: 650.jpg (deflated 8%)
#   adding: 44.jpg (deflated 10%)
#   adding: 171.jpg (deflated 9%)
#   adding: 500.jpg (deflated 8%)
#   adding: 87.jpg (deflated 8%)
#   adding: 647.jpg (deflated 9%)
#   adding: 77.jpg (deflated 8%)
#   adding: 103.jpg (deflated 9%)
#   adding: 995.jpg (deflated 9%)
#   adding: 730.jpg (deflated 9%)
#   adding: 292.jpg (deflated 9%)
#   adding: 556.jpg (deflated 9%)
#   adding: 249.jpg (deflated 10%)
#   adding: 301.jpg (deflated 10%)
#   adding: 744.jpg (deflated 9%)
#   adding: 49.jpg (deflated 9%)
#   adding: 952.jpg (deflated 9%)
#   adding: 45.jpg (deflated 10%)
#   adding: 34.jpg (deflated 9%)
#   adding: 920.jpg (deflated 8%)
#   adding: 458.jpg (deflated 9%)
#   adding: 400.jpg (deflated 10%)
#   adding: 904.jpg (deflated 9%)
#   adding: 859.jpg (deflated 10%)
#   adding: 39.jpg (deflated 9%)
#   adding: 63.jpg (deflated 9%)
#   adding: 654.jpg (deflated 10%)
#   adding: 324.jpg (deflated 9%)
#   adding: 547.jpg (deflated 9%)
#   adding: 146.jpg (deflated 8%)
#   adding: 539.jpg (deflated 8%)
# /home/keithlin/Code/Python/NYCU_DeepLearning_2025/HW2/2
